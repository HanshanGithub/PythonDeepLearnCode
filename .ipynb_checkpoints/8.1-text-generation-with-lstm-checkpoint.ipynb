# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
# import keras
import tensorflow as tf
import numpy as np

path = tf.keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %%
import  os

print('1:',os.getcwd()) #获取当前工作目录路径
print('2:',os.path.abspath('.')) #获取当前工作目录路径
print('3:',os.path.abspath('test.txt')) #获取当前目录文件下的工作目录路径
print('4:',os.path.abspath('..')) #获取当前工作的父目录 ！注意是父目录路径
print('5:',os.path.abspath(os.curdir)) #获取当前工作目录路径
# import sys
# print(sys.argv[0])
#输出
#本地路径
# Out:
# 1: E:\JupyterNotebook\Python 深度学习\first_edition
# 2: E:\JupyterNotebook\Python 深度学习\first_edition
# 3: E:\JupyterNotebook\Python 深度学习\first_edition\test.txt
# 4: E:\JupyterNotebook\Python 深度学习
# 5: E:\JupyterNotebook\Python 深度学习\first_edition

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 58
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
import tensorflow as tf
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3738
# --- Generating with seed: "d therefore
# has not taken and does not take root in german h"
# ------ temperature: 0.2
# d therefore
# has not taken and does not take root in german heart of the spirit and sacrificity of the state of the spiritual to be also interestive of the more account, and the artists and self-short of the spirit of the same and sense of the same and self-sentiment of the state of the spirit and self-exists the same the state of the spirit and self-sentiment of the developed and the contraling to the same intentional and self-evil the developed in the pre
# ------ temperature: 0.5
#  the same intentional and self-evil the developed in the present in the german consequently for impulses under the man in last a some man, and when in the more spirits of the continually to be a same present the senses the faith, in the contempt to one of the herable and conduct is a yet been interarary in itself the pride, one is the fact that the person as the present man is to be seems to man in the causarier what seems to are the interestive heart and
# ------ temperature: 1.0
# n the causarier what seems to are the interestive heart and decessed. one shorts the hectersment is any disuneflave not rul, only
# these
# mpracity of most still
# persists an
# antithic goods
# by being superfired, so act a will, were
# you as man for multt of hightlke that c"; sanuable. and wheke complitionoble how good free, not ano
# sa, that san ourselves
# simply discernablts its ourself on the short of the fundamental, are not to the what she
# ispe
# indigentita, ast
# ------ temperature: 1.2
# e fundamental, are not to the what she
# ispe
# indigentita, astrohy tomet." they leargn iodering dutory,
# has a dreamsfic, and
# whe called knowledge, but been ourself attenscal who psychelocy cave ylacking reasonhing--what is class facr. in its to feels not an reath--myself for a condition, or whee
# from that method"ly, that time hand, an
# its sam.
#
# penrest that digdous--even
# this pleaxuality, a dons. one he wyopes in but
# to their problesly inkeads of life to tak
# epoch 2
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3638
# --- Generating with seed: "l the stars understand. it is an
# additional instance of his "
# ------ temperature: 0.2
# l the stars understand. it is an
# additional instance of his conscious, in the subject of the subject and something in the spirit and bring to distance and conscious and former and society of the conscious and belief in the subjects of the subject and conscious the conscious existence of the subject for the spirit and discourse of the souls of the subject of the subject of the conscious and life of the subjects of the subjects of the super-interest in the s
# ------ temperature: 0.5
#  the subjects of the subjects of the super-interest in the subjects of the world souls of the final super-traint and conscious and for man; and the function of the scientification in the problem of the conscience in the good his own has healmed with the instincts of the world of the same entire and the same the comparison and instincts of light with all the conscious, delight of comparation of the presupte at once when it is predication of his stronge of t
# ------ temperature: 1.0
#  presupte at once when it is predication of his stronge of the so relation in socilical timed attain to dra, or "treat prices (in cnear and spirit.mquened will fee intlioun: pardont best here stopetnes science can seconn. a word
# of artists of feelinisfulance in the feelings of his
# errouscion of treaticoss for if would discom, ood sharded inflicious. [the psints to deslive its does also be desires? unone have there apparence of expecian confultine our in va
# ------ temperature: 1.2
#  unone have there apparence of expecian confultine our in vatue. we does-sot -no achgmed devely and besinu, like men, m feed on the bestifine there can "to machon original truth: as father
# and judgment withly of man falual
# pitshers of wo meeths some troceful intentional hours-"will how offvioh,en--as his method just that at least masters as resu,
# the him
# in, as fige, still foreing, such inlut
# e wild
# veluent withen for sure inwulr act the wiln metaphysical
# epoch 3
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3565
# --- Generating with seed: "ity called "prayer," the state of perpetual readiness for th"
# ------ temperature: 0.2
# ity called "prayer," the state of perpetual readiness for the fact that the sense of the standard that the same time as a still and the conscience of the superstitious and sympathy of the superstition of the same and self-contradict and the more and the sufferers of the conscience of the senses of the problem of the conscience of such a problem of the conscience of the spirit in the sense of the compare of the standard that the states of the antithese and
# ------ temperature: 0.5
# ompare of the standard that the states of the antithese and art and was deep that the last call the same truth and instructing to standard of a conscience of the subject that it is precisely that i seeks that it is a delight of the parties of the pathones. the will of its the from the creatoral and conscience of the disting and all called such an extended that the individuals which our age in every series and instincts and false the constance of experience
# ------ temperature: 1.0
# y series and instincts and false the constance of experience, "the on these made misple rest of estictians (be de"piction away in its bolkly kant and reluct delights"--in the sort of more
# coveron person fainuenic tranpass should have not learnable, thus aiting alterier perceive must alts. dut to mar; but with def. at
# one of things of comparative of indifference of a guart mit knowingly sitper it may not at for goner of whom whereverever walp our realmes of
# ------ temperature: 1.2
# ay not at for goner of whom whereverever walp our realmes of a highest no.
#
# 12offly occatecess
# and affince, more
# judice should be handigge, and and form of suceforice-fear of divine to slave
# of "allows and little man w;
# tourllove oneur-will hand "nemoes selfty and pain of that tessies and nervely as love of hardond and
# assvenirate
# commanding man lawbighes: there is a spote than dogially in the
# ploov that hy shared and soals
# art. his by
# syragor, has to he s
# epoch 4
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.3496
# --- Generating with seed: "ian--took first the side of reason; and, in fact,
# what did h"
# ------ temperature: 0.2
# ian--took first the side of reason; and, in fact,
# what did have been all the sense of the senses of the sense of the sense of the sense of the self-suffering of the sense of the sense of the same to the sense of the sense of the senses of the sense of the sense of the sense of the sense of the soul and consequences of the sense of the sense of the self-rests of the sense of the sense of the sense of the sense of the sense of the sense of the spirit and pro
# ------ temperature: 0.5
# of the sense of the sense of the sense of the spirit and proveral value in the present had it is not be attained for an again something had some good because they have not the protection of the rest and presence of the selfanct of the contemplation of the order to the sensation of the obligation of a protress of the world of the feeling of the events unselfish. the culture of the words of moral because of the general and consequences, it is a soul and far
# ------ temperature: 1.0
# cause of the general and consequences, it is a soul and far oneow grandting, could really rosted
# and glorion: the
# hrarsely thus being that the highinesomity and greatness and of their conscience and reounse
# manbysty strange towards place wese even--so the supersdice of necessick--how for "proposising to mankined makes rendence of emplong,y of a monstroning untances--as telies and
# degree uponances
# gloomarf the kood as it uponsibbeleentness of meofs of herve
# ------ temperature: 1.2
# gloomarf the kood as it uponsibbeleentness of meofs of herver euroophishzation of by a general excite precisely friend "slamence exsenedings, ochar, ratef--names in vely bust, that the trmood." are sectionusg, th" vulgable
# wula clofy naman, which after they differencely opinion from one's sei. brear moral colllarg, i must would be unuel keew or
# inventiymence
# agomingly (wemoriy instinct, or, east for particicately. to acausing of which
# is himself, rated
# xyn
# epoch 5
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3429
# --- Generating with seed: " not to speak of the
# wicked who are happy--a species about w"
# ------ temperature: 0.2
#  not to speak of the
# wicked who are happy--a species about which they have the stronger and self-religion and self-soul and in the sentiments and the present the strength of the subjection of the sense of the strength of the strength of the present the still and the present the fact themselves to the sense of the subjection of the reason and the man and senture of the spirit and interpretation of the state of the sentiments of the strength of the moral pre
# ------ temperature: 0.5
# the state of the sentiments of the strength of the moral precisely to its always they are to the moral man and ago that the subjection of the secort of the reason of all the man of those which the reausy are more intellectual present still personal promise which the sure and to a property of the concealed that the inventure that there is deceaver as the such all the profound disposition of the sharn are one of the profound it with the religion of the same
# ------ temperature: 1.0
# rn are one of the profound it with the religion of the same as a
# flact moralty of dunger for other removes
# risguble in him. they are down how to heads new guise within even to something case in moment moral foor sult of thomse are abord and reproglest with theke their comeed such its real place of elsewnal reverent action, they, however, even far
# human conceurance and femoly and
# dissolity of life, in suw, has dhee hiln feelings, there are hals h "persolung
# ------ temperature: 1.2
#  in suw, has dhee hiln feelings, there are hals h "persolung.
# the those live must just his own fellowshing as inesstared for dher what is a trued
# under--
# asegare and vibils, that new can been according ty, such idea welce ancess from humanimment
# of gradgire opination,
# feelsis, ye echitment personal -it is, that i hond that cate
# and not organicisus? "which misually
# schenee to fully or non refine superffediined individanal convictive upon thing is not timed
# epoch 6
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3383 0s - loss:
# --- Generating with seed: "such future europeans
# will probably be that of numerous, tal"
# ------ temperature: 0.2
# such future europeans
# will probably be that of numerous, talkeness of the sense of the spirit and the best one of the same taste of the spirit and the self-restroness of the self-religious and the most presumptor of the great the man and the self-consict of the present only the self-contines and and the present only and the self-religious and constitutes of the same such a precisely the present only and self self-consideress, and the self-contemplated and
# ------ temperature: 0.5
# ly and self self-consideress, and the self-contemplated and the philosophers, and in it, the in the mistaken, the more present has at once for the truth is the concerning in the mode of the god the sined and intellect of the same sympathy of a deceived and an a problem and are the religious distinguished in all the distinguant with himself the reason of humanity of things and the means of the man in all anything in the same and the earth and the developmen
# ------ temperature: 1.0
# in all anything in the same and the earth and the development of the attrect our preectively, and
# perhaps on all this attempted. these
# suffer unconditions, seeds the ardinut part the yecutered menly known that that
# in the faw anythinging and
# to finds our
# away and more belief in the oghing
# from the spirits all himself in all taste good na.piness may be a men "acts to different 'perfulce--this man often
# sensiplessly a polisgen (must blwinguble. folly resagra
# ------ temperature: 1.2
# ften
# sensiplessly a polisgen (must blwinguble. folly resagrable, inclie to think," gr own at ithe hital, aldentalday is, there, how
# stupting to na"--this
# "althought sandation, homeed venest        the
# histness: like
# commind,
# about truth a viewn."
#
# 1a
# knowledge, not rawricutely poddountarly still enemy, a lakes. but evehe, and more involuntaric
# under which lijves to pass, this
#  etheved by nation thiselves a tsle spirit of a most times, humby still time an a
# epoch 7
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3325
# --- Generating with seed: "he assertions of the founder of the church. so, too, it
# will"
# ------ temperature: 0.2
# he assertions of the founder of the church. so, too, it
# will not the sense of the same spirit and the sense of the consequently and also the spirit and the spirit and will be a morality of the same and an an an ancient man and also of the same and the standard and the constant things the standard of the same and an an an an ancestory and into the superstitions of the same and an antidfice of the same and refined spirit and an antidfered to be an action is
# ------ temperature: 0.5
# ame and refined spirit and an antidfered to be an action is into nothing in a certain mind and in the patience soul that the honest and who also true the evil as a discovering the most distance, is also have all the science, and in capacity of the european of the servict and an end superstitions of any man and into present mean any regreend the stand that is the best one any life than the moral type of the morality of all the spirit is also in the entire w
# ------ temperature: 1.0
# pe of the morality of all the spirit is also in the entire world would less
# destaniesfuly grosh toteks, inclead that origin.--on the elsewnot
# is philosophers, curisisioss: man account the acc his customs
# again dogid avoint the fut a
# think dnakining also of ears, extency,
# morein, this people and speaking;hantary, in anhingsw "impossiois hopent but dreaps in certainly, everything which harding; they turn to self place this to man furthers, hear
# regarded: but
# ------ temperature: 1.2
#  turn to self place this to man furthers, hear
# regarded: but disunarable heak is if an own made upon the glvelly
# sound
# clour--
#
#
# happiness
# in theirody of will
# not ssanicating and includurly
# will animal and sharr,
# has they in, thinkftely, indeed, nulcy, nepered, theiming--exceting, their  est necessares, now, comprerabilitywicluesh, but monking, another. only to things sinn suprosing, he spect, oran of rostous) wheredoe alreadys: betray feath many  i daile
# epoch 8
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.3262
# --- Generating with seed: "ess, imprudence, heartiness,
# and gaiety--in order to enjoy l"
# ------ temperature: 0.2
# ess, imprudence, heartiness,
# and gaiety--in order to enjoy like a man and in the sense of the same type of the same time to the world of the same time to the sense of the same type and also the fact the present man who so such a subject of the same since of the same and has a subject to the same time of the same time and some which the fact the same precisely to be a same and some which the same sain the same to the same being and the moral man and some pr
# ------ temperature: 0.5
# ain the same to the same being and the moral man and some predition to the fact of the man of the man of the suffering to which the same time still to finding to the desirable to the same notion in a subject to the philosophers and a sure, the formerly necessary the refinement who development and so the individual sense of moral concealed the man and to the refinement the must to be been to desirable, whose man, indeed, it is the same minds to some sunditi
# ------ temperature: 1.0
# ble, whose man, indeed, it is the same minds to some sundition, not belong to powerf an sutriginate into word it, himself, arriving than the only with the most values and sympathy, in
# conclusion in regide to platest, from thoreing wholly, but instinct and hen
#
# chesolitives, and could go with pually shar "give the take tarbibiess the inclules and unavotious
# commandert is individual worlds he still be for
# self derusical spite around further interpretation is
# ------ temperature: 1.2
# be for
# self derusical spite around further interpretation is lies even ty, which he is manifess thing, stoness
# originated badly, utgo to
# inexplind a daveine,
# fostity,
# at his
# soul it
# evitm, and
# theihntked proper tenaciinely of the tackilars" mare, formerly that it who increate his valually first day
# craaving strift among the kingublatily
# shuplibility where; , were already been been the
# falies is , without one
# can unusly sority. when inverly friends! who so
# epoch 9
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3222
# --- Generating with seed: "e who has (or discloses)
# an idea of the fact that philosophi"
# ------ temperature: 0.2
# e who has (or discloses)
# an idea of the fact that philosophisher of the same superioric and self-contradists a more and interpretation of the problem of the fact that the contrary and contemporaring the deceived the stronger and strong and developed always and superiority of the sense of the fact that the world of the same subtletoric and the art of the experience of the more of the subjection of the problem of the the and more of the super-of the or many
# ------ temperature: 0.5
# the problem of the the and more of the super-of the or many profound
# to the our as teres of life, his most reason to the good enough and
# constanting in the fact and interpretations to comes to a still striste for the
# constant in the world is a profound, the really be distinguished the result of the originated the subtle of such a force of the harder to an other things of regreenism in the present a suffering the world and so thinks, and interpretations and
# ------ temperature: 1.0
# a suffering the world and so thinks, and interpretations and ogh every threatess reed in old, dord blood. if young
# for
# excess of renorous a gerhe always
# that a man ane goever calt'-limble desire to pretance is the
# fashion, antlong esteel all thereto yet it is placed
# protest himself this young new coldous the value, and since that on all to the other instinct for noolity with an assilerrful, and more avill worre, will thor of sensctie the tendency of liol i
# ------ temperature: 1.2
# re avill worre, will thor of sensctie the tendency of liol intellitanles--sacrificed for long, felly omike dis:ably our others dependent desire in his xums of phentumous with name, it what notfors of a part of to therer glity intimpnated". whilighs. mucheling been expreting, men begins to them that stepiging nor e; nitestetly skepticismed its ade ew to compariood, is alwortone, originated like
# good, in allyes, it was an a coftens alnel, if
# one rewardant ob
# epoch 10
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.3178
# --- Generating with seed: "s confess it
# to ourselves; our itching is really the itching"
# ------ temperature: 0.2
# s confess it
# to ourselves; our itching is really the itching and also his own the consequently and the self-sentially and the states of the self-concerns the mind and the commonelorary and the states of the state of the self-sential protrequined and also the self-self-controlition of the self-sential such a protectoric of the great self-self-contrel the self-sentiment of the self-same to the general and the best the most conscience of the self-self-contrad
# ------ temperature: 0.5
# al and the best the most conscience of the self-self-contradicts of the action,
# who are to advantage and book to be say, in the feeling and the german does not inducest and have and also his conscience of the extent of general man, and all the
# protrenting consequently the tendency of the possibility of the sage of the end of discovered and the stronger and the still be taken of all the same a light of the taste-possibility in the instincts of the state of
# ------ temperature: 1.0
# t of the taste-possibility in the instincts of the state of well
# unlefed it are to stee utility in lic gnature, but then the daring
# of the state tooonkent
# also, all as itself
# are away bor to us" to or "philosophy periovy. so must new lowed to
# "sacrificed in presention, one our cause
# or delight" offers and discreeion and anitigat, we really advensabied and responsible conside condicess ch love like enoug a crompnicorsful there were by europe one paths. to i
# ------ temperature: 1.2
#  enoug a crompnicorsful there were by europe one paths. to is not ease, was thriching mar?; the whole to mueds his upersogicate right "time
# extent wart to not a great who ara? all noted--the artists the
# beginntd:
# more be well, than one fillk our most put indireningisty).. for a pripoly indurgace of the heaven "a difratley.
# . morawto so moquently with generally no ofthring manness dutiesn-hgfeeness hopughs to war aspe? to celemently forget when if the percu
# epoch 11
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3147
# --- Generating with seed: "d is there of
# a courage that is not ashamed of such humble l"
# ------ temperature: 0.2
# d is there of
# a courage that is not ashamed of such humble lighter and the supersition of the subject and there is a morality of the promise the sense of the souls and consideration of the entire and interestion of the subject and and the sublimates of the entire and the spirit of the originated and the sense of the conduct of the spirit of the ever the possible the proper to the spirit of the one of the process of the originated and and there is a man and
# ------ temperature: 0.5
#  of the process of the originated and and there is a man and most seemal and fact. but one must that we so the superiority of any greatest for one to be a deceives and one of the german sort of perceived and there is hear
# animalses, he great deeper, the believe the form of a morality for the entire perhaps there and wishes to possible conscience and the result of the regard to the deeper of the every false and problem are short of the latter of the form of
# ------ temperature: 1.0
# ery false and problem are short of the latter of the form of cunter of little cosisible,
# in heritely caulr; as so tertes!
#
# 54. he moveble imputing
# mertly, wheretoe took elevated, shontrony of the , and we from greater refection to morality must may perhaps as
# not been
# to kneash being, that some--when theie shollow of pressimes--and
# these venders the hreades: as i holder srobtlietician which is remain relicnty and consiutoous and wegulas kind as that althis
# ------ temperature: 1.2
# ain relicnty and consiutoous and wegulas kind as that althis arel-hered tranvaa:
# in the hand that its
# hunt? that the free man is p, priacious; too bee linerdive human and
# read honage for pleasure.talsmedy with degress: and when one which increpine one woupar on the echade
# instance min life ned
# certain
# possible when theive, any learn man!w, semfemens who cases" and wemuliad and myoharified, he is it is oblegions, and ie do they, will be despecort,
# than case
# epoch 12
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.3116
# --- Generating with seed: "est of mankind by logical discipline
# and training of the int"
# ------ temperature: 0.2
# est of mankind by logical discipline
# and training of the interpretation of the same things and subjection and same to the same to him is not the problem of the property and the comparative disposing the fact that the same to him, as the sense of the problem of the faculty of the problem of the problem of the subject and problem of the problem of the subject and superficial with the world of the conscience, and also the same and seems to the states of the p
# ------ temperature: 0.5
# nscience, and also the same and seems to the states of the problem and interpression of a such a problem strange are string and the great moralists
# of the problem of consolity to him an experience and conscience, and also not a more men to wishes to wame who slaver of interpretations, with streng to a gurated in the compulsion of the most ourselves. a problem of pain of such and the complated taste with the sense of the inclination of the faculty soul, we
# ------ temperature: 1.0
# e with the sense of the inclination of the faculty soul, we hisaring and giks them panchear himself finally begin seexisive most
# sufferings in ourverly know guisal domain of a doubt a popularly sunderingauritoring,--conclosry which were men a expedient act not heid they have something course of eposisions
# and gaves untray frequently in whole counterings to the kins of
# which they, he will taust partorion a spirit. thein which could ewricction
# with
# vulgarily
# ------ temperature: 1.2
# torion a spirit. thein which could ewricction
# with
# vulgarily seeen buldly
# delu christian trutiling friingly indscaution moantched among to
# ourmbol. ione; theirmen,
# would not
# impativity was, at
# language.
#
# 2p8agen, wonder of
# lowncely that all grandbluce
# restroyed's lopise as mische, some suphediaitiy: wellfzeent--the spirit to the domin scyoceed aacnical
# bad
# benecly foon
# foregm-sultip.--of famjower acalurness" from loftyine
# a
# pompaanually
# word
# "contempt trad
# epoch 13
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3086 0s -
# --- Generating with seed: "tice to christianity and its asiatic relatives--a thing impo"
# ------ temperature: 0.2
# tice to christianity and its asiatic relatives--a thing imposing of the profoundly and intention of the standard of the constitute them to be a sublimates of the consequently and the spirit and such a thing in the free spirits and such a man and almost the consequently and sense of the standard of the spirit of the entire and conscience of the standard of the spirit and self-contemption of the sense of the consequently and consequently the standing the sub
# ------ temperature: 0.5
# se of the consequently and consequently the standing the subtle personal men the future, the strength the part of the imperstity of the times of its sense and mankind to the unconditions of the process of the most reality in the assumptions, and any misunderstanding and considered to be a distinguish protection of the spirit and called mandifest is a man is heredit of a satisfaction had been always the instincision of the standing and superficial truth of
# ------ temperature: 1.0
# s the instincision of the standing and superficial truth of progress soin consolity itself out, understrically when to make them from the warn, the pleasure and lose fohed and tain pay bevogieary and places and con"w-partin lour and cause" for the manf adsarity,orfmenty, amedoy, appathed, in the shable, these obedience,
# to "lighted pass in the wprathable ycurse by book and pigs of the most
# possest could be
# comportanting about the
# faithred onee of this cult
# ------ temperature: 1.2
#  could be
# comportanting about the
# faithred onee of this cult. not puritalicy litine
# to have it becaume subtcedes and most
# best religic, a -emby a -farrings can cocrity: he wourd faurmen feigh and chordnablly
# sleving. "m other utterdly in
# uplacing, an actions. beboliation micledy
# relate!)
# pard; are sharg are wellfe beings.
#
#
# 1
#
# =trivinst one forwage it psychologicr thatsionime elemition wearompy" of the lack in some look nor hard", whichers: what rully
# the
# epoch 14
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.3055
# --- Generating with seed: "ion at any price and which inspire even in the most solitary"
# ------ temperature: 0.2
# ion at any price and which inspire even in the most solitary probably and act of the sense of the same to the sense of the subtlety of the states and distinction and soul in the same and soul in the same to the matter of the same and soul, the most destroys, and the states the sense of the sense of the same sense of the superiorical and self constantly problem of the superioric of the same and superioric and the superioric and begins to the same to the sam
# ------ temperature: 0.5
# erioric and the superioric and begins to the same to the same power of the low of rank."--the most and material conscience and the testament man be of the most responsibility of the most opinion of the soul and the man and that the one of the fundation for do not in the rest of thinking to a correaling of the soul seems and society, and proud, and his conscience, the sense of the
# spiritual senses of the spirit and conscience, and with a conscience to be a
# ------ temperature: 1.0
# of the spirit and conscience, and with a conscience to be a mea life out of that only berious. the disting burden a bound
# "german bote character, only the. but to christianty
# to whom we, are crays on this personal for nature is not will too may has deauns to the things becomes, at all danger, probably
# sasious retire,
# peopuder convensial gragming mankind be of lifebility, or
# we fine; the proquents us emotion are finer too-have been for spiritually nite take
# ------ temperature: 1.2
# us emotion are finer too-have been for spiritually nite takeing charms, act of that vatually bound-haat he so mnamies.--that the undreaponcy: the opinion of a =dabing of which only one is to calies,
# swear about the
# sense us states.  notking interpneity approcrnating verily the glor?nwwy re knowless"; in fortrility of relicogition of this organisk; in all the existery or of man. whyly,
# and is, is gains, and sensitification is pluptious tenke, i so musual ca
# epoch 15
# 1565/1565 [==============================] - 16s 11ms/step - loss: 1.3020
# --- Generating with seed: "nd still less that they
# wait in vain. occasionally, too, the"
# ------ temperature: 0.2
# nd still less that they
# wait in vain. occasionally, too, the subtain to the spirit and self-destructing the conscience of the state of the spirit and the standard and destructive intellectable and discired the struggle of the standard to the standard and destruction in the standard and soul--as a standard of the same taste of the spirit and the struction of the consideration of the spirit in the same task of the spirit and the standard to be something is a
# ------ temperature: 0.5
# ame task of the spirit and the standard to be something is all its believed that in the mind and heart, if the sense of the saint of the honor of things the fancous influence the minds and self spirit and place has not be dringulation of the good nowadays the fair species the good in the
# same and temportian with things his enemy many certainly precisely the stronger. as the history in the fact to instinct, in the greatest at last of natures of the principl
# ------ temperature: 1.0
# instinct, in the greatest at last of natures of the principling require insight that here invocation had to realst to existenocones, the cirring faith of ye so filling, and conscience is not the worts an similar--nantloc. i may
# "woman thing in listenal
# spicier of these has weters would doccen in the same lover, long, the hownt of disfalluned. -became sense's
# mindiest each philosophers," there is notlier esyeewitary tapay.
#
#
# 11e unition of his skies follvin
# ------ temperature: 1.2
# otlier esyeewitary tapay.
#
#
# 11e unition of his skies follving:
# we compuliate kan,--whergelf--this waries at party. if thes,
# they hh-opposmita
# error.--fines extination of "familm. he criding he
# among explains and from the name, in is origst," even to which idea itself
# clace the vaneszacanal--with. the chegruining in their caine probi?..
#
#
# 15
#
# =telt staged in the
# advance, their
# ity
# who wast plultnee -fat i now,
# and who conver, among solity,
# and
# masungted to
# epoch 16
# 1565/1565 [==============================] - ETA: 0s - loss: 1.298 - 17s 11ms/step - loss: 1.2985
# --- Generating with seed: "her body and her sexual gratification
# serves as an amply suf"
# ------ temperature: 0.2
# her body and her sexual gratification
# serves as an amply sufficient and something in the greatest and also the same to the contrary the sense of the proposition of the superiority of the sense of the problem of the contrary the stranger and something in the senses of the sense of the sense of the propermition and conscience of the sense of the sense of the same superseation of the free spirits of the sense of the conduct and also the distinguish and and an
# ------ temperature: 0.5
# the sense of the conduct and also the distinguish and and antificial, and the domain of its
# demonstring as though to one will not the state the attached. the first and the
# disinterection and for the convince of man of the fathers of the problem and grappines to the sense of the same sense of a distinguish in so he state untruthing of the man absolutely of the races and desires and supersection of the assumed to still be for the free is difficult that the w
# ------ temperature: 1.0
# the assumed to still be for the free is difficult that the wilize remain will as. for their gives gold,
# everything, noced, about them, and bodigs upor
# as any
# any restran teking, the correspond the (ance, sympathy, science, they a man, in this (absolute untruths to generalss, lw of gloriging, codience of time slove!
# his imisalsuic darking
# that apart of by the state to victoryary cromps and strong and mendsmen, and
# ask--atart
# instincted, and although the res
# ------ temperature: 1.2
# nd mendsmen, and
# ask--atart
# instincted, and although the resilal, virtwine there is, and like in such peoms
# easubles. thought down brought to there enotis, limoneffy,
# in its brigning, is predvaif's; in
# contrary oneselyness is disters, psypbain, now in moral, theirly sever risge?tufful good--which: ! i far ne therefore, movings victory, os
# express a much. schutar
# sful, "favounts, in danger, and there is
# one
# que the tantary,
# only that stlessness
# thus of open
# epoch 17
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2956
# --- Generating with seed: "am: to their goal. though within us the hereditary habit of
# "
# ------ temperature: 0.2
# am: to their goal. though within us the hereditary habit of
# the self-same to the self-soul when the sense and the sense of the sense of the same and the contrary and the promises and the stronger and superstite of the souls and instincts of the same and conscience of the same and the stronger that it is all the discoversing the spirit and even of the self-same to the states and contemplation of the same and most successful the states and the standpoint of
# ------ temperature: 0.5
# e same and most successful the states and the standpoint of the fating that when in the same times of the same intellect of general recisted by this conception the stronger discire that is as a despises do what the stronger that the sout the stronger and spirit in the same simply at the other more readint and every seems to the occulring do the spirit in the reality of the same thorear, which the desires
# and bad and the intellect as a continues and the con
# ------ temperature: 1.0
# desires
# and bad and the intellect as a continues and the conception to the deponces hitherto to
# meanscet.nef"), the
# possible hings and
# consequence the bride and sontte sick to even a offity. outh play cousate from alnat self--atached manifeste to be opinion, herizond in the sake of the strength reduct man, or gradually power, within himself.--amolitfud, he
# conceivary. in
# one in the truthful god, into estame of historical, rightoodhwiness and immulable reli
# ------ temperature: 1.2
# nto estame of historical, rightoodhwiness and immulable religious know, nothing must we constitute of
# ead, the strungly
# scurfully--ill, if the stimul rins--pit pover into coldectis of whatever-powers reverence
# at
# chemove ultimately tible "rm"s raskable, getund; encleded. indeness,
# surtible forgured by hear
# over artists, who: weq!-pys, in willing discoursep--smiltaigze. forthy may not to instance of truch thorake on being finer ropeverach wepever of good, o
# epoch 18
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2939
# --- Generating with seed: "during repose in the lap of a dull, animal, plant-like
# indol"
# ------ temperature: 0.2
# during repose in the lap of a dull, animal, plant-like
# indolented the fact it is the present destiny the constitute the stree the conservative of the profounder and spirit of the sense of the constitute the same and profound, and all the streed in the same command and destrained and sense and series of the sense of the profounder and sense of the same sense the interreason and self-contempt of the spirit and sense of the same profound, and and the same spi
# ------ temperature: 0.5
#  spirit and sense of the same profound, and and the same spirit sensition and appears and some reason
# to the virtue and certain the species
# in the sense of the definite of the error, in the same and measure in a further of history of the most measures of the fact of the opinion of the same point of a strightlic constrained there are something of the common
# made it is a sense of the present experiences and formula of the imigliration of the pleasure of the
#
# ------ temperature: 1.0
# nces and formula of the imigliration of the pleasure of the
# impsetic ullice growther from its amilady of a morals soult: no been immoral" is parach away knows at once have thousands of spirit opinion, to a portion may
# whether unwe, and some
# rue, it,
# with such
# command" and stands to makes and the opes something in flade himself, for which, sunfult to all some the command--aar delicy worlds as virtue of the many phoshes--vewerars," being equalfilably enough
# ------ temperature: 1.2
# e of the many phoshes--vewerars," being equalfilably enough to-o;itiwigen
# time
# hered was to wislopiby in tetchone thope lays ohsnoms essentially
# spirit and suprectanary; the measscy". tere on undifgnena;enessnic rehuace burief!--how clomby "the actions the first of the m feminity, moreaclwaring to oursy of abist is conditions should not eventue ! there race
# our view, swealy listrust that sucle comfortion of
# ly what seamss, lespeants" had stating still cat
#
# epoch 19
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2909
# --- Generating with seed: "
# reached down even to ourselves and our present world. in or"
# ------ temperature: 0.2
#
# reached down even to ourselves and our present world. in order to the man and and the substitute and self-contradict of the self-contradiction of the same and the substitute of the subject and intellect and self-contrady and so that the sense of the self-contradiction and the sense of the sense of the problem of the delight of the sense of the same and self-contradict and self-contrady and the soul and become that the sense of the soul in the sense of the
# ------ temperature: 0.5
# ul and become that the sense of the soul in the sense of the tasktity and general and that is all the same and self-contradifued and good in the new the profounder of the and intellectually and intercourses of the spiritual with the profounders and "hereposing that as it is that as a woman the commanding and good in the conduct a profounder and hath which so that only to lich it see the most man and one with the sense of the other bad a concerning the trou
# ------ temperature: 1.0
# nd one with the sense of the other bad a concerning the trousous conscience, leading death reducies, harres, blins that phyaps the state with the conception of the german
# visienac
# language, and finds and but that. then calmoss, or main of manner-life and lustian had so (happy, and if been
# find, that vereous, desired the sympathy--which he who system, that metaphysic
# had him he was only seep it is also the hath from point of mers last hat which he sacreon,-
# ------ temperature: 1.2
# also the hath from point of mers last hat which he sacreon,-hom oswisting, is not an ill suicifulty worch an
# activer
# does the less
# jemeggenes, give this mapred helpaw
# upon, it implied teaches
# a trour knowledge, for evil hard--languals--siguriousness
# the moble-ito",
# reasoniering
# that france resicker, what a hual-language aristlent nativer very hat qunds securioes!--confiming world." this as a --rowsly to, for the
# cheldment
# and then, and never miss important
# epoch 20
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2888
# --- Generating with seed: "n on him. the latter
# obeys a superior and hence feels no res"
# ------ temperature: 0.2
# n on him. the latter
# obeys a superior and hence feels no restraint to the property of the supersision of the man of the sense of the standard of the more readily a more of the spirit of the more of the profound to the same and desires of the same of the supersictiman the more of the consequence of the strength of the supersine of the sense of the property of the man has always as the deeper and despises a consequence of the sense of the person with the sup
# ------ temperature: 0.5
# spises a consequence of the sense of the person with the supersictimer man of the "goodness of the mistakes of the exacted although as the formultatilable and consideration of the reality speaks of the problem of the conduct and the same and things the worth of an almost opinions, where all the respectance of the fact that the "mind and their reality of the spirit and more of the standard of what is the domain of the ethical man proper the standard of the
# ------ temperature: 1.0
# is the domain of the ethical man proper the standard of the so eduations,
# acts at the ockidence and realify wull clusion of
# u-song the most infinite gaves, the "salvalical
# and pach open taste of pleasure to art and regard as pompentation of musictedy, when immemering,
# as to the
# psychologist of his find with their strengintually philosophers, is a sylofity, man of their mere sake a man would be being
# arts--in everything runibity of the pride" very interrogi
# ------ temperature: 1.2
# ng
# arts--in everything runibity of the pride" very interrogibe, in ewseprom. but abnteable waty; humanity
# does a does the
# always our
# bede,--ye nle.. the
# lustice of old graduall thing
# has toinnesss of a dominen virtue.sanning fearta
# dignotoomed.
#      too
# never
# adress of estaftwepaspy justifition joyih, christiang of the world over on ological convertional hound howe meater the sure. all of man whofff, in gossivnify of
# comtulled?"--as-say
# the
# di case a house
# epoch 21
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2861
# --- Generating with seed: "ct) along
# with the old testament into one book, as the "bibl"
# ------ temperature: 0.2
# ct) along
# with the old testament into one book, as the "bible, and in the same time and interests of the same and conscience of the same to the contempt to the same to the same and contempt to the same to the contempt to the same and contempted to the simply of the same and contempt to the same and superficialities and man as the contempt to him is to be and contempt to the man and accordance of the spirit of the same and such an of the same to the same to
# ------ temperature: 0.5
# he spirit of the same and such an of the same to the same to the sense of the world becaused as
# C:\Users\16340\AppData\Local\Temp/ipykernel_18620/2163503365.py:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# the examples of the armistakes and the gelood to all the interestice, the have the dangerous and personal sick in the same something of the taste of himself the respectatedly something same is a comparative and superstimes the value of the mass of the most men of contempt to the same to a fact of the of the hands and according to the nation is through and the st
# ------ temperature: 1.0
#  the hands and according to the nation is through and the still so could have the dibernt a "dreame idea to conflatrous to wants moralingsks,  every higher met of minked conceals against the crast a thrie path on every monurnest times of our femoly alcontering to a nourisher just fast pitshing it knows no noory of the graditary for the charm of goethe about food and an to all of that acts to the sexually worked: a thinks securition of the sensition of that
# ------ temperature: 1.2
# exually worked: a thinks securition of the sensition of that (or a conather of acqueitive little, and
# nothing to gaiud gorman in yet to a love yea, nporation may from clace, how
# it who will
# that, let no. one fraihings--the will of reversed, and only only our
# enewre" "is; to make infliction.
# at oneoked imperitxquevers of "caines when the arkwarels od at the
# cushrsomment of p
# quarition,--nasure, a conduct,
# its you art and mosuctorouseds; for naching amsysus
# epoch 22
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2848
# --- Generating with seed: "eive only the unpleasant consequences of evil-doing, and pra"
# ------ temperature: 0.2
# eive only the unpleasant consequences of evil-doing, and praise, the morality and the problem of the consentuty, and an actions of the contempt of the problem of the constitute the actions of the consentuss. the more intellectually the way of the problem of the consentuss, and the artists of the consentuss, and the constitute the men to the constitute the consentutiess of the presential conscience of the spirit and something who has not at least the proble
# ------ temperature: 0.5
#  of the spirit and something who has not at least the problem in the continually the man of its circussofful about himself. we have attast
# and foregrings and consequence of the consentes of all the surpleness--the dangeristic and he has does not believed ones, the spirit and something has not to be a senses of an interroact and superficities and
# consentusness, and concerning the super-true the free distinguish the provete that the first in the moral things
# ------ temperature: 1.0
# e distinguish the provete that the first in the moral things this belief in other depose
# mediocris.
# that all
# presuble
# form, one may among very morality of the
# spirits; and
# suffers evil; it is "the religions growing
# and contrany" shehe duals? praise--for yingonding titles something
# something rearoutive highly another, a mean grationable and teclation ip
# soun as it. xwitt that our marny reflumment, sufficiently nothing
# has in the miraces,
# believes, the sacri
# ------ temperature: 1.2
# sufficiently nothing
# has in the miraces,
# believes, the sacrifice, perhaps prove? however, nopes to germanion"--when the imoul, inflicts of come immoral!
#
# 1
# asis around from metaphysis. -exclpecceffaadiane together (which
# who made hundless
# aathobiun, and reclusive)-posisness
# morality to her besided
# thought. a dragenff", even as -philosophy. but that one of the ploood as at
# lited in the chelderable
# beever-have meanble loigsted he "hatbends
# depataulfumpule" h
# epoch 23
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2820
# --- Generating with seed: "g to the
# circumstance that we germans are as yet nearer to b"
# ------ temperature: 0.2
# g to the
# circumstance that we germans are as yet nearer to be also the same to the same to the same and superstition of the sense of the superior of the struggle and the states and and in the sublity of the sublity of the strength of the same time and also, as the problem of the same taste of the sublity of the strength, and the strength of the sublity of the scientific and in the superition of the profoundly of the sublity of the sublity of superior of th
# ------ temperature: 0.5
# e profoundly of the sublity of the sublity of superior of the called and an antide in the fact that the suffering to counter--and if a probably self-life is the state of
# man of the end that is all this strength of the same
# to the same who soul and as
# ------ temperature: 1.0
#                                                                             consequen-dioun, which is ne antiour mode of ip sublitys
# ...
# that the father of every act always the least and
# foremority of the science, fo
# ------ temperature: 1.0
# every act always the least and
# foremority of the science, for the least are and races of a
# religious corress.=--it is no means, knowledge man words and in his sy estaus of all
# that diric, is thus is not comeds, in which is all the
# it
# immortays.
# prespain imbels
# ratribes that he never yus impersectuance, of
# the ageising, too seath--anticastantic an-last learns--thus, the dingle good the rest knowledge
# of his attenthing, what general woman, in these
# far upon
# ------ temperature: 1.2
# dge
# of his attenthing, what general woman, in these
# far upon as
# is it onlys and give nor-kooped with a
# sickmed for over-fictol):
# own
# sodpecal. has been of look in us utofwice of his skeptocal is born misone? alyt in moralsshly tenprus.=--the more culture-addiction has than
# flar himself of art, cinlianment
# you
# to consider,-su!
# howven,wit. buked veny european,
# ad of which termin regard as
# full bexigely human ham and tease for their me-thous
# should yet to que
# epoch 53
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.2429 0s - loss
# --- Generating with seed: "e to its retreating light. and speaking seriously, it
# is a f"
# ------ temperature: 0.2
# e to its retreating light. and speaking seriously, it
# is a fact that it is the protection of the spirit of the spirit of the proful the man of the spirit of the spirit of the spirit of the man of the spirit of the scientific complete of the sense of the spirit of the spirit of the spirit of the fact of the soul and man of the scientific and spirit of the man of the spirit of the man of the spirit of the conception of the problem of the spirit of the sense
# ------ temperature: 0.5
# of the conception of the problem of the spirit of the sense is not to himself, and his presentem of view of the most instincts to conferce of
# the subtle and suffering to the conceptions of the piety of the right in the way that i have hitherto deconsiments with the same will a personal grat of the soul is ever himself of the superficial great and delight to the good and histoner and susagians of the spirit has not to heart and should be more hardon--this m
# ------ temperature: 1.0
# he spirit has not to heart and should be more hardon--this more and dangers of romounp). they thus just have sound of the sensen follow believwding. we are trageery
# of respoine cultured pries intorm, recoust of this chooles it may love to his tender risticic bedouts are suy, and evententwy--in errapt with this person only formerly a motive of fought in pyied--without special oghtored, rangs and
# soul is not learnable nourismodes as
# disposentary man to the p
# ------ temperature: 1.2
# ul is not learnable nourismodes as
# disposentary man to the point recalme,
# of turnians
# himfur? however faith hoster: we do i semptate oner in himself, no
# draw of their hetes evinces idongaiing through that, which is to
# instinct is necesse" as liug!
# if one coult for this
# pave, is one mean drest he slaving, if, though to-hands for which most deed as ventrese's apars. concerning kinds iranhable their philosaris of
# mindpretimants, seivently dullermen
# life wetel
# epoch 54
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.2408
# --- Generating with seed: "on of the bible. the distorted and diseased
# in his own natur"
# ------ temperature: 0.2
# on of the bible. the distorted and diseased
# in his own nature of the problem of a man is a man and as a most desire to be well of the subtle men to a soul and the fact that the sense of the subtle own still be the former depreciation of the end that who are stronger and destruction of the same soul and the most man with the sense of the stronger of the problem of the fact that the subtle words of the same of the consideration of the stronger and subtle of
# ------ temperature: 0.5
# the same of the consideration of the stronger and subtle of the confunderous expedient and the words. for the world of the word and artible that it was only of the soul and revenge, the one another with the same the depression of the word of the complicate in the formelly and intellectual succession which perhaps be discipline itself as a man in the same of the free spirit of a fact as is consequently and also be the case it was a man and in the entire imp
# ------ temperature: 1.0
# ntly and also be the case it was a man and in the entire impresensitions which attraciamisity." by men, weep the downgens: the taste is
# the auguss of wisd it year only europeaa
# giving in from the higher
# falical
# pursest and theoric man"--he is religion of the sin form
# to "god," enpither with such a firve is remains, that the will and belief.--exercited of refented, in the religious self-lach in feeling with
# which is in it, some evil almost undistinguties up
# ------ temperature: 1.2
# ling with
# which is in it, some evil almost undistinguties upinder? is fieldy?--the disciplitimity with mediod are in(-abother--so that meanc? at a new would tasted
# of
# ideasly for the chiles within man-rey the tendenal questione there is a-day ho
# here, diseachese, the doste of philosophical socul--he loves, but with to schoped withting pronuglt and unfualing as
# signiof to
# themie, especially to tas because it still doubture, also is only inutered en arbitra
# epoch 55
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.2417
# --- Generating with seed: "erfectly, hesitatingly, and with compulsion the small, short"
# ------ temperature: 0.2
# erfectly, hesitatingly, and with compulsion the small, short of the science of the saints of the man of the spirit of the strength and also the distinguishes and something in the manifested and all the considerated and the problem of the reason of the account of the spirit of the contemporaring and some time of the actions of the considerated and such a man and the human and discirly of the same to the strength and something in the spirit of the considerat
# ------ temperature: 0.5
# o the strength and something in the spirit of the consideration and the young passions of the problem of the proper to the measure, and the and one and consising the mimment of the action the bad and personal and suffering and conscience, and the free hime to the strangely, perhaps now to called the strength explancal and delicate and called aged, so that it is the problem is the world of such a matter that it is more the recognized that ic, and this is on
# ------ temperature: 1.0
# atter that it is more the recognized that ic, and this is only a prover being scientification; we has, he circumscele and races, they harrow a egmpty the germans and
# least more against like them when
# some vengeance of their morality brandfully. the extending,
# and as a art of manwet to
# soul that the roped that rule, even to a descrey on single satisfaity and in itgly that is to nothing stagles irresse's
# come to under the acaly, man to meaning gives accom--y
# ------ temperature: 1.2
# sse's
# come to under the acaly, man to meaning gives accom--youth--that humbifultyness
# sorre,
# as pentarion
# from which a billbrment in greadfus opensing of is satisfad the black. the precisely that sum the moding part of ple"s live.--that kasify the unchilor. in every me, putten would e time of the sympathy,
# or at onever.
# szaus among general
# obsuration of the jesuas the
# unresponsion, that untell,
# centiment--softencumest,--which, wis "hue has
# to a constrancis
# epoch 56
# 1565/1565 [==============================] - 16s 10ms/step - loss: 1.2414
# --- Generating with seed: "cs connected with intellectual
# capacity.
#
#
# 60
#
# =desire for v"
# ------ temperature: 0.2
# cs connected with intellectual
# capacity.
#
#
# 60
#
# =desire for view of the same problement of the man as the same which the spirit and the same philosophers are still out of the same man, the same words and such a proposision of the spirit of the same and the spirit of the stronger of the same proper to the master of the same philosophers is a man is a consequence of the same man is a man as the superiority of the same proposition of the same person and the se
# ------ temperature: 0.5
# iority of the same proposition of the same person and the sense and tenders to the last resolution, as we make the case of the same personal and the same men that all the best of a spirit and
# the care." the influence of the conscience of life, and the contradism, for the tenders of our egreat of emotion of the scientific unfortunate the words of which the moral and cannot at once that it takes of the soles, which the influence of the great condition as the
# ------ temperature: 1.0
# the soles, which the influence of the great condition as they from their could
# to this destructical exaggeration of its owe the presumption of man" this new must damke is most statingation of the frech, as a socrates,--this anvisked of compuratise decides oper to rankess of wegoing to common, for a socration,ian, when have more and the classion and have with which, sentive their both renerves this gain at the same percip sainte insists the concliditak spor
# ------ temperature: 1.2
#  gain at the same percip sainte insists the concliditak sporming! that is not made mustifines, ver-marvely, error thereby
# teble,
# sacrinatial., i suscefforiations: the cases one who rate himself: that it really with human telle-bany, how in "subject than christian. hand and , phensigne: it tums of somell voly an omeke, for the demous writinessul,
# for the veritably kay of its immediation
# from evilouring, order art. "say," because"--morality could
# looghs in g
# epoch 57
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2384
# --- Generating with seed: " through all the vanity, through all the
# noise which is natu"
# ------ temperature: 0.2
#  through all the vanity, through all the
# noise which is nature, it is the greatest originated and something is the same sense of the spirit of the stronger and superficial of the conception of the spirit of the spirit of the same against the sense of the spirit of the contradictority of the contradict of the spirit of the spirit of the world and superficial in the most stronger and present consideration of the contradition of the man of the spirit of the s
# ------ temperature: 0.5
# ration of the contradition of the man of the spirit of the spirit of the moral purplemerd in the present comple and complexity of pleasure in the hostilvess and the moral superiority of the similar spirit of the science of the knowledge the will and instincts of the should have no longer the descaim to the best of a man in bodication of the same hands and pain of the personal stristings usefulness and there is not be accest in the "could from a most devilr
# ------ temperature: 1.0
#  and there is not be accest in the "could from a most devilrious and predocipome man moy.
#
#
# itse. the faith? clew?yomment it would remains without which they have under the firsorations, who chance, thinled, and botrment.
#
# noze a general mislikest explie" instincting moral world all gradations of european could be commander-mother world without themselves i have so nature with which the new an meeps
# solation with more iblos the, all
# piol and like us in oth
# ------ temperature: 1.2
# ps
# solation with more iblos the, all
# piol and like us in other
# storm ariseding an old irigrous course-even "we meine as craceful in inst heak
# co.
# man i had must probablings at in body to sum itmless "-the that last nature of
# ele glover sensecy in very suscetered by they
# whother time and matter look endaving comfared, lexination, but a sducust add athesespjnaticglittly conferd thinh
# objugne (suilty were fung the "luxiges
# schoolgly, "greatesome; how or-reclu
# epoch 58
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2383
# --- Generating with seed: "
# variations, and yet we should know ourselves as an invariab"
# ------ temperature: 0.2
#
# variations, and yet we should know ourselves as an invariably and reverence of the spirit of the spirit and conscience of the spirit of the states of the spirit of the most desire to the states of the most discreate the man of the spirit of the problem of the greatest and the conscience of the spirit and derivation of the spirit of the spirit of the same taste of the most experience and something in the states of the spirit and the superstition of the wor
# ------ temperature: 0.5
#  in the states of the spirit and the superstition of the world of freedom. the general happen from the problem and taste of a must be dispanhed to the appearance in every perposition for the spirit of his spirit and transform of man in such a conduct, so that his elevated and relations of a man will be all the philosopher, as a definitane who not on the disposine suffering in the elevation is the good over the mask,ail of the states of deceive here and cau
# ------ temperature: 1.0
# good over the mask,ail of the states of deceive here and cause in delusion of a retacration a recognized less above, to ceporde on the actains and precisely this opinion
# of rank in ounmea and sympathy. unconduenty, and hostlity and charrianed and law remains of a benevolly often, and so far acce
# stupings of
# implilimant seek: that i mean the
# worlds.
#
#
# 9offogbble compersived
# self-periots according to a sourcess majelad for the genuine ple, that i god. namely
# ------ temperature: 1.2
# o a sourcess majelad for the genuine ple, that i god. namely, then the opinion therous necously, we lorcening bred of any
# would of
# albus, we take. to comtursityance, "this beevener sacrifice must  coulingter
# pied of total anys.
#
#
# 1itely bellave merely
# nuk--fferist foolousl's
# experience theughed. wrictably ippesitius, lossing,, finer, -.oqque
# tjougot." to linee, but
# will: to learn like deptureing all
# superncously," and to realor
# upbal intere-youth.
#
# .]
#
#
# =z
# epoch 59
# 1565/1565 [==============================] - 17s 11ms/step - loss: 1.2388
# --- Generating with seed: "would even
# allow myself to rank philosophers according to th"
# ------ temperature: 0.2
# would even
# allow myself to rank philosophers according to the state of the states of the most science, and all the conception of the spirit of the spirit of the fact that it is a profound of the science of the most contempt to the best of the same distinction of the spirit and sensition of the spirit of the same and something in the spirit of the soul and the problem of the spirit of the most sort of the spirit and the spirit of the proper power, and all t
# ------ temperature: 0.5
#  of the spirit and the spirit of the proper power, and all the discourse of false and so that will a still
# exightiness of the commander is all the finally of the soul and happiness of the best of the disposition and solething morality of some sort of which the soul of life of the world many point of the owing souls
# as the soul east a progression and also only of the good and slaved something more and of the case which a fair rest
# of the stinle of his own b
# ------ temperature: 1.0
# and of the case which a fair rest
# of the stinle of his own being has increase of the states; or a fascincality to it is a for, and becomdances of a world demands from nature, the let that it is misinterioral antampicates the promisemate continues east has to course of it as teling, morally been an otherwise in
# this same can falseons bebotions:
# is the good man has wind something the
# insts of greek life more is well incabry, seems to first at present
# but tha
# ------ temperature: 1.2
# life more is well incabry, seems to first at present
# but than this
# question helists ragerises, for shishy
# ndure
# wicke, only long.--of every hunt
# fredistely,--every glower above, to boundrathy misafsible for himself (sures thought) sea romeetness against ranvers of monely besimater-mivin, primation at a man such
# nowadays. a very absolqury, imonghunntary spirits in
# onejlopilee,
# owe still modient german honec origin: he last knows as i my "good" consatismant

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
